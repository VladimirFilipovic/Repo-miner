# %%
# Cell 1: Import Libraries and Set Up
import os
import json
import re
import numpy as np
import nltk
import enchant
from collections import Counter
from pygments import lex
from pygments.lexers import get_lexer_by_name, find_lexer_class
from pygments.token import Token
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('words')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
english_dict = enchant.Dict("en_US")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Vladimir
# [nltk_data]     Filipovic\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Vladimir
# [nltk_data]     Filipovic\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Vladimir
# [nltk_data]     Filipovic\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Vladimir
# [nltk_data]     Filipovic\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package words to C:\Users\Vladimir
# [nltk_data]     Filipovic\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
# Cell 2: Define Functions for Comment Extraction and Preprocessing

def extract_comments_from_file(file_path, language):
    comments = []
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
        code = file.read()
        if language == "Jupyter Notebook":
            language = "Python"
        lexer = get_lexer_by_name(language)
        tokens = list(lex(code, lexer))
        for token_type, token_value in tokens:
            if token_type in Token.Comment:
                comments.append(token_value.strip())
    return comments

def preprocess_text(text):
    text = re.sub(r'\W+', ' ', text)
    tokens = word_tokenize(text.lower())
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words and english_dict.check(token)]
    return ' '.join(tokens)

def get_extensions(language):
    # Define extensions for supported languages
    extensions = {
        "Python": [".py"],
        "JavaScript": [".js"],
        "Java": [".java"],
        "Jupyter Notebook": [".ipynb"],
        "C++": [".cpp", ".h"],
        "R": [".r"],
        "LiveScript": [".ls"],
        "Fortran": [".f", ".f90"],
        "C": [".c", ".h"],
        "C#": [".cs"],
        "Go": [".go"],
        "Ruby": [".rb"],
        "Rust": [".rs"],
        "Swift": [".swift"],
        "Kotlin": [".kt"],
        "Scala": [".scala"],
        "PHP": [".php"],
        "TypeScript": [".ts"],
        "Mathematica": [".nb"],
        "Perl": [".pl"],
        "Haskell": [".hs"],
        "Lua": [".lua"],
        "Julia": [".jl"],
        "Shell": [".sh"],
        "Objective-C": [".m"],
        # Add more languages and their extensions here
    }
    return extensions.get(language, [])

# %%
# Cell 3: Process Repository

def process_repository(directory, language, repo_name):
    if not get_extensions(language):
        return {repo_name: "Can't process"}

    all_comments = ''

    for root, _, files in os.walk(directory):
        for file in files:
            if any(file.endswith(ext) for ext in get_extensions(language)):
                file_path = os.path.join(root, file)
                comments = extract_comments_from_file(file_path, language)
                all_comments += ' '.join(comments)
    
    # Preprocess comments and combine them into a single string
    flat_comments =  preprocess_text(all_comments)
    
    return {repo_name: flat_comments}

# %%
#Cell 4: Analyze Repositories

def analyze_repositories(base_directory, repo_languages):
    results = {}


    for repo in os.listdir(base_directory):
        repo_path = os.path.join(base_directory, repo)


        if os.path.isdir(repo_path):
            # Log
            print(f"Processing {repo}")
            language = repo_languages.get(repo, "UnsupportedLanguage")
            is_supported = get_extensions(language) != []
            print(f"Language: {language}")
            if not is_supported:
                print(f"Can't process {repo} as it is not a supported language")
                results[repo] = "Can't process"
            else:
                repo_results = process_repository(repo_path, language, repo)
                results.update(repo_results)
    return results

# %%
# Cell 5: Main Execution


base_directory = '../data/repos/'

# Load repository languages from JSON file
with open('repo-languages.json', 'r') as f:
    repo_languages = json.load(f)


results = analyze_repositories(base_directory, repo_languages)

with open('repository_comments.json', 'w', encoding='utf-8') as outfile:
    json.dump(results, outfile, ensure_ascii=False, indent=4)

print("Analysis complete. Results saved to repository_comments.json")
# Out:
# Processing 0tt3r
# Language: C
# Processing 1-part
# Language: UnsupportedLanguage
# Can't process 1-part as it is not a supported language
# Processing 1234zou
# Language: Fortran
# Processing 3T
# Language: Jupyter Notebook
# Processing 510004015
# Language: JavaScript
# Processing 7enTropy7
# Language: Jupyter Notebook
# Processing 89996462
# Language: JavaScript
# Processing aa75017730
# Language: JavaScript
# Processing aarontrowbridge
# Language: Unknown
# Can't process aarontrowbridge as it is not a supported language
# Processing abdullahkhalids
# Language: Jupyter Notebook
# Processing absolute-quantum
# Language: Python
# Processing acheong08
# Language: Go
# Processing AdhesionTek
# Language: JavaScript
# Processing advancesoftcorp
# Language: Fortran
# Processing AgnostiqHQ
# Language: Python
# Processing AI4Finance-Foundation
# Language: Python
# Processing aiidateam
# Language: Python
# Processing ajz34
# Language: Jupyter Notebook
# Processing alejomonbar
# Language: Jupyter Notebook
# Processing alexandersgreen
# Language: Haskell
# Processing alibaba
# Language: Python
# Processing Alice-Bob-SW
# Language: Python
# Processing alpha87
# Language: JavaScript
# Processing amartyabose
# Language: Julia
# Processing amazon-braket
# Language: Python
# Processing amazon-braket-examples
# Language: Shell
# Processing amcdawes
# Language: Jupyter Notebook
# Processing AminKaramlou
# Language: Jupyter Notebook
# Processing amschel99
# Language: Rust
# Processing amyami187
# Language: PostScript
# Can't process amyami187 as it is not a supported language
# Processing Andrew-S-Rosen
# Language: Python
# Processing anedumla
# Language: Python
# Processing Anish-M-code
# Language: Python
# Processing anonymousr007
# Language: Unknown
# Can't process anonymousr007 as it is not a supported language
# Processing Antimonit
# Language: Kotlin
# Processing antontutoveanu
# Language: JavaScript
# Processing anyehttp
# Language: JavaScript
# Processing aoterodelaroza
# Language: Fortran
# Processing Apress
# Language: C++
# Processing Argyle-Software
# Language: Rust
# Processing ArlineQ
# Language: Python
# Processing aromanro
# Language: C++
# Processing artificial-brain
# Language: Python
# Processing artificial-scientist-lab
# Language: Python
# Processing artiste-qb-net
# Language: Jupyter Notebook
# Processing aryashah2k
# Language: Jupyter Notebook
# Processing atilafassina
# Language: TypeScript
# Processing atulvarshneya
# Language: Python
# Processing Aurelien-Pelissier
# Language: Python
# Processing AustenLamacraft
# Language: JavaScript
# Processing Avarok-Cybersecurity
# Language: Rust
# Processing awhite862
# Language: Python
# Processing aws-samples
# Language: Jupyter Notebook
# Processing awslabs
# Language: TypeScript
# Processing badlogic
# Language: Java
# Processing bagmk
# Language: Jupyter Notebook
# Processing baidu
# Language: Python
# Processing BAQIS-Quantum
# Language: Python
# Processing bartubisgin
# Language: Jupyter Notebook
# Processing BBN-Q
# Language: Julia
# Processing BeerMoneyDev
# Language: TypeScript
# Processing ben-albrecht
# Language: Python
# Processing bernwo
# Language: Mathematica
# Processing betakernel
# Language: JavaScript
# Processing binghuang2018
# Language: Python
# Processing bjader
# Language: Python
# Processing block-hczhai
# Language: C++
# Processing bmedicke
# Language: Jupyter Notebook
# Processing bol-edu
# Language: C++
# Processing BoltzmannEntropy
# Language: Jupyter Notebook
# Processing BoothGroup
# Language: Python
# Processing boschmitt
# Language: C++
# Processing Boulder-Cryogenic-Quantum-Testbed
# Language: Python
# Processing BQSKit
# Language: Python
# Processing brucefan1983
# Language: Cuda
# Can't process brucefan1983 as it is not a supported language
# Processing brunojulia
# Language: C#
# Processing brunorijsman
# Language: Python
# Processing bsenjean
# Language: Jupyter Notebook
# Processing Budapest-Quantum-Computing-Group
# Language: Python
# Processing bwesterb
# Language: Go
# Processing bytedance
# Language: Python
# Processing BYUCamachoLab
# Language: Python
# Processing cailab-tamu
# Language: Jupyter Notebook
# Processing camitava0321
# Language: Jupyter Notebook
# Processing caphindsight
# Language: C#
# Processing carstenbauer
# Language: Julia
# Processing carstenblank
# Language: Python
# Processing catho
# Language: JavaScript
# Processing ccicconetti
# Language: Python
# Processing cda-tum
# Language: C++
# Processing cduck
# Language: Python
# Processing CERN
# Language: Unknown
# Can't process CERN as it is not a supported language
# Processing CERN-IT-INNOVATION
# Language: Python
# Processing cgoo4
# Language: R
# Processing cgranade
# Language: Python
# Processing chetanbhat
# Language: TypeScript
# Processing chpxu
# Language: TypeScript
# Processing Christophe-pere
# Language: Jupyter Notebook
# Processing christorange
# Language: Python
# Processing cisasteelersfan
# Language: Python
# Processing Classiq
# Language: Jupyter Notebook
# Processing cloudflare
# Language: C
# Processing Cloudslab
# Language: Java
# Processing ClydeTime
# Language: JavaScript
# Processing cmendl
# Language: C
# Processing cmsi
# Language: Fortran
# Processing cohensbw
# Language: Julia
# Processing Colfenor
# Language: Rust
# Processing CompPhysics
# Language: PostScript
# Can't process CompPhysics as it is not a supported language
# Processing contepablod
# Language: Jupyter Notebook
# Processing corbett
# Language: Python
# Processing corigan01
# Language: Rust
# Processing cp2k
# Language: Fortran
# Processing CQCL
# Language: Python
# Processing CQuIC
# Language: Unknown
# Can't process CQuIC as it is not a supported language
# Processing CrawfordGroup
# Language: Python
# Processing crazy4pi314
# Language: Jupyter Notebook
# Processing Crivella
# Language: Shell
# Processing croppers
# Language: Jupyter Notebook
# Processing crossutility
# Language: JavaScript
# Processing cryptosubtlety
# Language: Unknown
# Can't process cryptosubtlety as it is not a supported language
# Processing ctuning
# Language: Python
# Processing cyllab
# Language: JavaScript
# Processing czy13724
# Language: JavaScript
# Processing dabacon
# Language: Python
# Processing dakk
# Language: Python
# Processing dalcorso
# Language: Unknown
# Can't process dalcorso as it is not a supported language
# Processing DarkStarStrix
# Language: Python
# Processing dartmouth-cs98
# Language: JavaScript
# Processing Dashlane
# Language: TypeScript
# Processing dauphine-dev
# Language: JavaScript
# Processing David20122
# Language: C#
# Processing davidbkemp
# Language: JavaScript
# Processing davidbuterez
# Language: Python
# Processing DavitKhach
# Language: Jupyter Notebook
# Processing dceresoli
# Language: Fortran
# Processing deepchem
# Language: Python
# Processing deepqmc
# Language: Python
# Processing DeepQuantumNeuralNetworks
# Language: PostScript
# Can't process DeepQuantumNeuralNetworks as it is not a supported language
# Processing deezertidal
# Language: JavaScript
# Processing delapuente
# Language: Rust
# Processing DelMaestroGroup
# Language: C++
# Processing denvitko
# Language: Python
# Processing DesignrKnight
# Language: JavaScript
# Processing desireevl
# Language: Python
# Processing detrin
# Language: Julia
# Processing developer-student-club-thapar
# Language: Jupyter Notebook
# Processing dibondar
# Language: Jupyter Notebook
# Processing diffqc
# Language: Python
# Processing DikshantDulal
# Language: Jupyter Notebook
# Processing diracq
# Language: Jupyter Notebook
# Processing dot-open
# Language: C#
# Processing DPotoyan
# Language: Jupyter Notebook
# Processing DRA-chaos
# Language: Jupyter Notebook
# Processing dsh0416
# Language: Jupyter Notebook
# Processing dsvip
# Language: JavaScript
# Processing DVLab-NTU
# Language: Unknown
# Can't process DVLab-NTU as it is not a supported language
# Processing dwave-examples
# Language: Python
# Processing dwavesystems
# Language: Python
# Processing dylan-jayatilaka
# Language: Perl
# Processing dynamiqs
# Language: Python
# Processing dynexcoin
# Language: C++
# Processing echkon
# Language: Jupyter Notebook
# Processing eclipse-qrisp
# Language: Python
# Processing Edric-Matwiejew
# Language: Python
# Processing elecV2
# Language: JavaScript
# Processing elisezhu123
# Language: Unknown
# Can't process elisezhu123 as it is not a supported language
# Processing emirhanai
# Language: Unknown
# Can't process emirhanai as it is not a supported language
# Processing Emotion-Prediction-with-Quantum5-Neural-Network-AI-Machine-Learning
# Language: Unknown
# Can't process Emotion-Prediction-with-Quantum5-Neural-Network-AI-Machine-Learning as it is not a supported language
# Processing enchanted123
# Language: Python
# Processing Entanglion
# Language: Unknown
# Can't process Entanglion as it is not a supported language
# Processing entropicalabs
# Language: Python
# Processing epelaaez
# Language: Jupyter Notebook
# Processing ericardomuten
# Language: Jupyter Notebook
# Processing ericchansen
# Language: Python
# Processing ertuil
# Language: Python
# Processing euphoricrhino
# Language: Go
# Processing evaleev
# Language: Unknown
# Can't process evaleev as it is not a supported language
# Processing evanhockings
# Language: Julia
# Processing EverettYou
# Language: Jupyter Notebook
# Processing evilbutcher
# Language: JavaScript
# Processing ewt-project
# Language: Python
# Processing exaexa
# Language: C++
# Processing exo7math
# Language: Python
# Processing EyalRozenberg1
# Language: Python
# Processing Fanerst
# Language: Python
# Processing fbm2718
# Language: Python
# Processing fbuessen
# Language: C++
# Processing fedimser
# Language: Python
# Processing FermiQC
# Language: Julia
# Processing fevangelista
# Language: Jupyter Notebook
# Processing fiasqo-io
# Language: Jupyter Notebook
# Processing FiloSottile
# Language: Go
# Processing fisherstevenk
# Language: Java
# Processing flynnbr11
# Language: Python
# Processing foxyproxy
# Language: JavaScript
# Processing frankforte
# Language: PHP
# Processing FujiiLabCollaboration
# Language: Jupyter Notebook
# Processing fvmassoli
# Language: Jupyter Notebook
# Processing garymooney
# Language: Python
# Processing gdsfactory
# Language: Python
# Processing gecrooks
# Language: Python
# Processing gedaskir
# Language: Python
# Processing gendx
# Language: Rust
# Processing geosim
# Language: Python
# Processing ghb24
# Language: Unknown
# Can't process ghb24 as it is not a supported language
# Processing gigabit101
# Language: Java
# Processing GiggleLiu
# Language: Julia
# Processing gitkarma
# Language: Jupyter Notebook
# Processing glassnotes
# Language: Jupyter Notebook
# Processing GN006
# Language: JavaScript
# Processing gncs
# Language: Python
# Processing goodchemistryco
# Language: Python
# Processing google
# Language: Python
# Processing goropikari
# Language: Dockerfile
# Can't process goropikari as it is not a supported language
# Processing GQCG
# Language: C++
# Processing GregDMeyer
# Language: Python
# Processing grey-area
# Language: Python
# Processing grimme-lab
# Language: Fortran
# Processing GroenteLepel
# Language: Python
# Processing GTorlai
# Language: Jupyter Notebook
# Processing guardiora
# Language: JavaScript
# Processing guochu
# Language: Julia
# Processing guruvamsi-policharla
# Language: Rust
# Processing gxggxl
# Language: JavaScript
# Processing haimengzhao
# Language: Jupyter Notebook
# Processing hande-qmc
# Language: Fortran
# Processing Hanrui-Wang
# Language: Python
# Processing harshangrjn
# Language: Julia
# Processing hashberg-io
# Language: Python
# Processing hebrewsnabla
# Language: Mathematica
# Processing Hedilict
# Language: Unknown
# Can't process Hedilict as it is not a supported language
# Processing higher-order-quantum-reservoir
# Language: Python
# Processing hjkgrp
# Language: Python
# Processing hongyehu
# Language: Jupyter Notebook
# Processing howecheung
# Language: Unknown
# Can't process howecheung as it is not a supported language
# Processing HPQC-LABS
# Language: MATLAB
# Can't process HPQC-LABS as it is not a supported language
# Processing HQSquantumsimulations
# Language: Python
# Processing hrachya-zakaryan
# Language: Python
# Processing hsavit1
# Language: Unknown
# Can't process hsavit1 as it is not a supported language
# Processing hsim13372
# Language: Jupyter Notebook
# Processing hsinyuan-huang
# Language: C++
# Processing HuangJunye
# Language: Jupyter Notebook
# Processing huangli712
# Language: Fortran
# Processing huckiyang
# Language: Python
# Processing HugoStrand
# Language: Jupyter Notebook
# Processing HyQD
# Language: Python
# Processing hywong2
# Language: Unknown
# Can't process hywong2 as it is not a supported language
# Processing I-am-R-E
# Language: Unknown
# Can't process I-am-R-E as it is not a supported language
# Processing IBM
# Language: Unknown
# Can't process IBM as it is not a supported language
# Processing IBM-Quantum-Technical-Enablement
# Language: Python
# Processing iccmr-quantum
# Language: Jupyter Notebook
# Processing ichuang
# Language: Python
# Processing id77
# Language: JavaScript
# Processing IETF-Hackathon
# Language: Java
# Processing IgorBrandao42
# Language: Python
# Processing iitis
# Language: Julia
# Processing IKEDAKAZUKI
# Language: Jupyter Notebook
# Processing Indi-Quantum-Community
# Language: Unknown
# Can't process Indi-Quantum-Community as it is not a supported language
# Processing indian-institute-of-science-qc
# Language: Python
# Processing indisoluble
# Language: Swift
# Processing Infleqtion
# Language: Python
# Processing inQWIRE
# Language: Coq
# Can't process inQWIRE as it is not a supported language
# Processing intel
# Language: C++
# Processing IntelligentQuantum
# Language: TSX
# Can't process IntelligentQuantum as it is not a supported language
# Processing ionq
# Language: Python
# Processing iqm-finland
# Language: Python
# Processing isaracorp
# Language: C
# Processing issp-center-dev
# Language: C
# Processing itsubaki
# Language: Go
# Processing itzmeanjan
# Language: C++
# Processing IUCVLab
# Language: Jupyter Notebook
# Processing IvanIsCoding
# Language: Jupyter Notebook
# Processing ivanmurashko
# Language: PostScript
# Can't process ivanmurashko as it is not a supported language
# Processing Izheil
# Language: JavaScript
# Processing JackHidary
# Language: Jupyter Notebook
# Processing JaGeo
# Language: Python
# Processing JanLahmann
# Language: Jupyter Notebook
# Processing JannickWeisshaupt
# Language: Python
# Processing JarvisLee0423
# Language: MQL4
# Can't process JarvisLee0423 as it is not a supported language
# Processing JavaFXpert
# Language: Lua
# Processing Jayshah25
# Language: PowerShell
# Can't process Jayshah25 as it is not a supported language
# Processing jcmgray
# Language: Python
# Processing jcosborn
# Language: Nim
# Can't process jcosborn as it is not a supported language
# Processing jd-opensource
# Language: Python
# Processing jebej
# Language: Julia
# Processing Jejz168
# Language: JavaScript
# Processing jfeist
# Language: Julia
# Processing jiyanjiang
# Language: PostScript
# Can't process jiyanjiang as it is not a supported language
# Processing johanvos
# Language: Java
# Processing JohnCoogan
# Language: Unknown
# Can't process JohnCoogan as it is not a supported language
# Processing Jone2008
# Language: JavaScript
# Processing JordanovSJ
# Language: Unknown
# Can't process JordanovSJ as it is not a supported language
# Processing joselado
# Language: Python
# Processing JoSQUANTUM
# Language: Jupyter Notebook
# Processing jpzwolak
# Language: Jupyter Notebook
# Processing JQub
# Language: Jupyter Notebook
# Processing jrick
# Language: Go
# Processing jschanck
# Language: Python
# Processing jtiosue
# Language: C++
# Processing juanjosegarciaripoll
# Language: C++
# Processing JuliaQuantum
# Language: Julia
# Processing JuliaQuantumControl
# Language: Julia
# Processing JuliaQX
# Language: Julia
# Processing jw-12138
# Language: Vue
# Can't process jw-12138 as it is not a supported language
# Processing jwa7
# Language: Jupyter Notebook
# Processing kareldonk
# Language: C++
# Processing kayanouriko
# Language: JavaScript
# Processing kemperlab
# Language: Python
# Processing kevinkawchak
# Language: Unknown
# Can't process kevinkawchak as it is not a supported language
# Processing kit-cel
# Language: Jupyter Notebook
# Processing kite
# Language: Unknown
# Can't process kite as it is not a supported language
# Processing kjfx
# Language: Unknown
# Can't process kjfx as it is not a supported language
# Processing kjssad
# Language: Lua
# Processing KOP-XIAO
# Language: JavaScript
# Processing kpdemetriou
# Language: C
# Processing KPRoche
# Language: Python
# Processing krishnakumarsekar
# Language: Unknown
# Can't process krishnakumarsekar as it is not a supported language
# Processing kriskwiatkowski
# Language: Assembly
# Can't process kriskwiatkowski as it is not a supported language
# Processing kudelskisecurity
# Language: Go
# Processing kurtsiefer
# Language: C
# Processing kwant-project
# Language: Jupyter Notebook
# Processing KwiatLab
# Language: Python
# Processing langkhach270389
# Language: Unknown
# Can't process langkhach270389 as it is not a supported language
# Processing lanl
# Language: Python
# Processing lanl-ansi
# Language: Julia
# Processing latticesurgery-com
# Language: Python
# Processing LauraGentini
# Language: Jupyter Notebook
# Processing lehner
# Language: Python
# Processing Leticia-maria
# Language: Julia
# Processing LiangYi520
# Language: JavaScript
# Processing LiaoChinTe
# Language: Python
# Processing libint
# Language: Unknown
# Can't process libint as it is not a supported language
# Processing liboqs
# Language: C
# Processing libra-code
# Language: Unknown
# Can't process libra-code as it is not a supported language
# Processing libtangle
# Language: Jupyter Notebook
# Processing lijikun
# Language: Shell
# Processing lin-lin
# Language: Unknown
# Can't process lin-lin as it is not a supported language
# Processing LinkedInLearning
# Language: Jupyter Notebook
# Processing Liu-group
# Language: Python
# Processing LiuJPhys
# Language: Python
# Processing liumian97
# Language: Java
# Processing Lizaterdag
# Language: Unknown
# Can't process Lizaterdag as it is not a supported language
# Processing llens
# Language: Python
# Processing LLNL
# Language: C++
# Processing lmacken
# Language: Python
# Processing lmmentel
# Language: Jupyter Notebook
# Processing lneuhaus
# Language: Python
# Processing lockwo
# Language: Jupyter Notebook
# Processing Lonitch
# Language: Jupyter Notebook
# Processing louishrm
# Language: Jupyter Notebook
# Processing LovedGM
# Language: Unknown
# Can't process LovedGM as it is not a supported language
# Processing lrcfmd
# Language: Python
# Processing LSchatzki
# Language: Unknown
# Can't process LSchatzki as it is not a supported language
# Processing Lubycon
# Language: JavaScript
# Processing luca-parisi
# Language: Python
# Processing LuchnikovI
# Language: Python
# Processing luqui
# Language: Haskell
# Processing lutqhysky
# Language: Unknown
# Can't process lutqhysky as it is not a supported language
# Processing luxfi
# Language: Solidity
# Can't process luxfi as it is not a supported language
# Processing LWKJJONAK
# Language: Jupyter Notebook
# Processing lynkco01
# Language: Unknown
# Can't process lynkco01 as it is not a supported language
# Processing lynnlangit
# Language: Jupyter Notebook
# Processing m-labs
# Language: Python
# Processing maartenvd
# Language: Julia
# Processing machinelevel
# Language: JavaScript
# Processing mapmeld
# Language: TypeScript
# Processing marcobn
# Language: Jupyter Notebook
# Processing mareksubocz
# Language: Jupyter Notebook
# Processing maria-violaris
# Language: Jupyter Notebook
# Processing mariiatuzovska
# Language: Go
# Processing MarioKrenn6240
# Language: MATLAB
# Can't process MarioKrenn6240 as it is not a supported language
# Processing markusschmitt
# Language: Python
# Processing marl0ny
# Language: JavaScript
# Processing Marol62926
# Language: Unknown
# Can't process Marol62926 as it is not a supported language
# Processing marvel-nccr
# Language: Unknown
# Can't process marvel-nccr as it is not a supported language
# Processing Matematija
# Language: Python
# Processing materialscloud-org
# Language: IDL
# Can't process materialscloud-org as it is not a supported language
# Processing materialsvirtuallab
# Language: Python
# Processing matheusmtta
# Language: Jupyter Notebook
# Processing mathworks
# Language: Unknown
# Can't process mathworks as it is not a supported language
# Processing matrixbud
# Language: Unknown
# Can't process matrixbud as it is not a supported language
# Processing matt-lourens
# Language: Python
# Processing matteoacrossi
# Language: Jupyter Notebook
# Processing maximer-v
# Language: Jupyter Notebook
# Processing mayabenowitz
# Language: Jupyter Notebook
# Processing Mc-Zen
# Language: Typst
# Can't process Mc-Zen as it is not a supported language
# Processing MCdasheng
# Language: JavaScript
# Processing mcoggins96
# Language: Python
# Processing meamy
# Language: Unknown
# Can't process meamy as it is not a supported language
# Processing MeikelLP
# Language: C#
# Processing merzlab
# Language: C
# Processing metaphorical
# Language: Python
# Processing mgg39
# Language: Unknown
# Can't process mgg39 as it is not a supported language
# Processing mhsmathew
# Language: Jupyter Notebook
# Processing mickahell
# Language: Dockerfile
# Can't process mickahell as it is not a supported language
# Processing microsoft
# Language: Jupyter Notebook
# Processing MicrosoftDocs
# Language: Python
# Processing mikeroyal
# Language: Q#
# Can't process mikeroyal as it is not a supported language
# Processing mindspore-ai
# Language: Python
# Processing mit-han-lab
# Language: Jupyter Notebook
# Processing MolSSI
# Language: Python
# Processing MolSSI-BSE
# Language: Python
# Processing MonitSharma
# Language: Jupyter Notebook
# Processing monkey6468
# Language: JavaScript
# Processing mortele
# Language: C++
# Processing mozilla
# Language: JavaScript
# Processing mrtkp9993
# Language: Python
# Processing MSCNUAN
# Language: Unknown
# Can't process MSCNUAN as it is not a supported language
# Processing Mshakir-Git
# Language: JavaScript
# Processing mspronesti
# Language: Python
# Processing mstechly
# Language: Jupyter Notebook
# Processing mthiim
# Language: Java
# Processing MuonRay
# Language: Python
# Processing mupq
# Language: C
# Processing mxgmn
# Language: C#
# Processing mymagicpower
# Language: JavaScript
# Processing NanFeng683
# Language: Apex
# Can't process NanFeng683 as it is not a supported language
# Processing nathanieljohnston
# Language: MATLAB
# Can't process nathanieljohnston as it is not a supported language
# Processing nathanshammah
# Language: Jupyter Notebook
# Processing NCKU-QFort
# Language: Julia
# Processing NECI_STABLE
# Language: Unknown
# Can't process NECI_STABLE as it is not a supported language
# Processing neilpanchal
# Language: Unknown
# Can't process neilpanchal as it is not a supported language
# Processing NeoKode
# Language: JavaScript
# Processing netket
# Language: Python
# Processing Neurogram-R
# Language: JavaScript
# Processing ngnrsaa
# Language: C++
# Processing nitesh-prasad
# Language: Assembly
# Can't process nitesh-prasad as it is not a supported language
# Processing Nix-QChem
# Language: Diff
# Can't process Nix-QChem as it is not a supported language
# Processing node-red-quantum
# Language: JavaScript
# Processing NorbertZare
# Language: Python
# Processing NTU-ALComLab
# Language: C
# Processing NuclearPhysicsWorkshops
# Language: Jupyter Notebook
# Processing numericalEFT
# Language: Julia
# Processing numqi
# Language: Python
# Processing NVIDIA
# Language: Jupyter Notebook
# Processing OJB-Quantum
# Language: Jupyter Notebook
# Processing OminiaVincit
# Language: Python
# Processing OnionyTeam
# Language: C++
# Processing open-quantum-safe
# Language: C
# Processing openforcefield
# Language: Python
# Processing openqasm
# Language: Python
# Processing openquantumhardware
# Language: Jupyter Notebook
# Processing oqc-community
# Language: Python
# Processing ORCAQuantumChemistry
# Language: Unknown
# Can't process ORCAQuantumChemistry as it is not a supported language
# Processing oreilly-qc
# Language: Jupyter Notebook
# Processing OriginQ
# Language: C++
# Processing Orz-3
# Language: JavaScript
# Processing oscarhiggott
# Language: C++
# Processing osscar-org
# Language: Jupyter Notebook
# Processing outmansec
# Language: Unknown
# Can't process outmansec as it is not a supported language
# Processing ozaner
# Language: Python
# Processing ozwaldorf
# Language: Unknown
# Can't process ozwaldorf as it is not a supported language
# Processing p0cisk
# Language: Python
# Processing pablosanjose
# Language: Julia
# Processing PacktPublishing
# Language: Jupyter Notebook
# Processing PaddlePaddle
# Language: Jupyter Notebook
# Processing Pamblam
# Language: JavaScript
# Processing panqec
# Language: Python
# Processing pasqal-io
# Language: Python
# Processing paulehoffman
# Language: Unknown
# Can't process paulehoffman as it is not a supported language
# Processing paulmillr
# Language: TypeScript
# Processing PaulWAyers
# Language: Jupyter Notebook
# Processing pauxy-qmc
# Language: Python
# Processing peastman
# Language: Python
# Processing PennyLaneAI
# Language: Python
# Processing Perfecto-Quantum
# Language: Java
# Processing pfloos
# Language: Unknown
# Can't process pfloos as it is not a supported language
# Processing photonmang
# Language: JavaScript
# Processing pittquantum
# Language: Python
# Processing pm936
# Language: JavaScript
# Processing pmocz
# Language: Python
# Processing pnnl
# Language: OpenQASM
# Can't process pnnl as it is not a supported language
# Processing poig
# Language: Unknown
# Can't process poig as it is not a supported language
# Processing pouriya73
# Language: Q#
# Can't process pouriya73 as it is not a supported language
# Processing ppqm
# Language: Python
# Processing PQClean
# Language: C
# Processing PQShield
# Language: JavaScript
# Processing pranabdas
# Language: Jupyter Notebook
# Processing pranavdurai10
# Language: Python
# Processing praveenb7
# Language: Unknown
# Can't process praveenb7 as it is not a supported language
# Processing ProjectQ-Framework
# Language: Python
# Processing projekter
# Language: OpenQASM
# Can't process projekter as it is not a supported language
# Processing proRamLOGO
# Language: Jupyter Notebook
# Processing psi4
# Language: C++
# Processing pykao
# Language: Python
# Processing PyMatching
# Language: C++
# Processing pyRiemann
# Language: Python
# Processing pyscf
# Language: Python
# Processing Q-Compiler
# Language: Mathematica
# Processing Q-solvers
# Language: C++
# Processing Qaintum
# Language: Julia
# Processing Qaqarot
# Language: Python
# Processing qBraid
# Language: Jupyter Notebook
# Processing QC-Edu
# Language: Python
# Processing qc-tum
# Language: Python
# Processing QC2023-Group-3
# Language: Python
# Processing qcc4cp
# Language: C++
# Processing qcdb
# Language: Python
# Processing QCHackers
# Language: Python
# Processing QChASM
# Language: Python
# Processing qchemsoftware
# Language: AGS Script
# Can't process qchemsoftware as it is not a supported language
# Processing qclib
# Language: Python
# Processing QCmonk
# Language: Python
# Processing qcserenity
# Language: C++
# Processing qcxms
# Language: Fortran
# Processing qc_portfolio_optimization
# Language: TypeScript
# Processing qdevpsi3
# Language: Jupyter Notebook
# Processing QE-Lab
# Language: Rust
# Processing QEF
# Language: Unknown
# Can't process QEF as it is not a supported language
# Processing qgrad
# Language: Python
# Processing qiboteam
# Language: Python
# Processing qigitphannover
# Language: PostScript
# Can't process qigitphannover as it is not a supported language
# Processing qilimanjaro-tech
# Language: Python
# Processing qir-alliance
# Language: C++
# Processing Qiskit
# Language: OpenQASM
# Can't process Qiskit as it is not a supported language
# Processing qiskit-community
# Language: Jupyter Notebook
# Processing Qiskit-Extensions
# Language: Python
# Processing qiskrypt
# Language: Python
# Processing QKDNetSim
# Language: C++
# Processing qlan3
# Language: Python
# Processing QMCPACK
# Language: C++
# Processing qml-benchmarks
# Language: Python
# Processing qmlcode
# Language: Fortran
# Processing qniapp
# Language: JavaScript
# Processing qojulia
# Language: Julia
# Processing qonwaygameoflife
# Language: Python
# Processing qosf
# Language: Jupyter Notebook
# Processing qpic
# Language: Python
# Processing QPong
# Language: Python
# Processing QPower-Research
# Language: Jupyter Notebook
# Processing qrefine
# Language: Python
# Processing qsb-dev
# Language: C#
# Processing qsppack
# Language: Jupyter Notebook
# Processing QTechTheory
# Language: Mathematica
# Processing QTI-TH
# Language: Jupyter Notebook
# Processing qu-tan-um
# Language: OpenQASM
# Can't process qu-tan-um as it is not a supported language
# Processing qua-platform
# Language: Python
# Processing QuAcK
# Language: Unknown
# Can't process QuAcK as it is not a supported language
# Processing Quandela
# Language: Python
# Processing QuanEstimation
# Language: Julia
# Processing quantastica
# Language: JavaScript
# Processing Quantomatic
# Language: OpenQASM
# Can't process Quantomatic as it is not a supported language
# Processing quantshah
# Language: Jupyter Notebook
# Processing quantum
# Language: C
# Processing Quantum-Accelerators
# Language: Python
# Processing Quantum-Classical-Hyrid-Neural-Network-for-binary-image-classification-using-PyTorch-Qiskit-pipeline
# Language: Jupyter Notebook
# Processing quantum-compiler
# Language: OpenQASM
# Can't process quantum-compiler as it is not a supported language
# Processing quantum-computing-exploration-for-drug-discovery-on-aws
# Language: TypeScript
# Processing quantum-dan
# Language: Jupyter Notebook
# Processing Quantum-Dynamics-Hub
# Language: Unknown
# Can't process Quantum-Dynamics-Hub as it is not a supported language
# Processing quantum-elixir
# Language: Elixir
# Can't process quantum-elixir as it is not a supported language
# Processing Quantum-Flytrap
# Language: TypeScript
# Processing Quantum-Game
# Language: Vue
# Can't process Quantum-Game as it is not a supported language
# Processing quantum-journal
# Language: Apex
# Can't process quantum-journal as it is not a supported language
# Processing quantum-kite
# Language: Unknown
# Can't process quantum-kite as it is not a supported language
# Processing quantum-kittens
# Language: Python
# Processing quantum-machine-learning
# Language: Jupyter Notebook
# Processing Quantum-Manager
# Language: JavaScript
# Processing Quantum-Many-Body
# Language: Julia
# Processing quantum-mob
# Language: Mathematica
# Processing Quantum-OCS
# Language: Python
# Processing quantum-ods
# Language: Unknown
# Can't process quantum-ods as it is not a supported language
# Processing Quantum-Red
# Language: Unknown
# Can't process Quantum-Red as it is not a supported language
# Processing quantum-rose
# Language: Vue
# Can't process quantum-rose as it is not a supported language
# Processing Quantum-Safe-OpenSSH
# Language: C
# Processing quantum-tinkerer
# Language: Python
# Processing quantum-tokyo
# Language: Jupyter Notebook
# Processing Quantum-Universal-Education
# Language: TypeScript
# Processing quantum-visualizations
# Language: Python
# Processing Quantumacy
# Language: Unknown
# Can't process Quantumacy as it is not a supported language
# Processing QuantumBFS
# Language: Julia
# Processing QuantumComputingLab
# Language: C++
# Processing quantumdb
# Language: Java
# Processing quantumformalism
# Language: Unknown
# Can't process quantumformalism as it is not a supported language
# Processing quantumgizmos
# Language: Python
# Processing quantumjim
# Language: Jupyter Notebook
# Processing quantumlabUB
# Language: C#
# Processing quantumlib
# Language: Python
# Processing QuantumPackage
# Language: Shell
# Processing QuantumQuipu
# Language: Jupyter Notebook
# Processing QuantumSavory
# Language: Julia
# Processing QuantumServer
# Language: C++
# Processing quantumsim
# Language: Python
# Processing QuantumVillage
# Language: C
# Processing QUARK-framework
# Language: Python
# Processing qubekit
# Language: Python
# Processing qubit-science-club
# Language: Python
# Processing qubrabench
# Language: Python
# Processing qucat
# Language: Jupyter Notebook
# Processing qudoor
# Language: Python
# Processing QuEraComputing
# Language: Julia
# Processing QuEST-Kit
# Language: C
# Processing quil-lang
# Language: Apex
# Can't process quil-lang as it is not a supported language
# Processing qulacs
# Language: Jupyter Notebook
# Processing Qulacs-Osaka
# Language: Jupyter Notebook
# Processing QunaSys
# Language: Jupyter Notebook
# Processing QuSTaR
# Language: Python
# Processing QuState
# Language: Rust
# Processing QutacQuantum
# Language: Python
# Processing qutech
# Language: Python
# Processing QuTech-Delft
# Language: Python
# Processing qutip
# Language: Python
# Processing qwqmlf
# Language: Jupyter Notebook
# Processing QWWAD
# Language: C++
# Processing R-Sweke
# Language: Jupyter Notebook
# Processing RafaelGoulartB
# Language: JavaScript
# Processing RagBagCN
# Language: JavaScript
# Processing rakytap
# Language: C++
# Processing ray-pH
# Language: GDScript
# Can't process ray-pH as it is not a supported language
# Processing rdisipio
# Language: Python
# Processing redfx-quantum
# Language: Java
# Processing refraction-ray
# Language: Python
# Processing rehaanahmad2013
# Language: Unknown
# Can't process rehaanahmad2013 as it is not a supported language
# Processing Renmusxd
# Language: Rust
# Processing rigetti
# Language: Python
# Processing rishab-partha
# Language: Jupyter Notebook
# Processing rmlarose
# Language: Jupyter Notebook
# Processing rodyherrera
# Language: JavaScript
# Processing rogercolbeck
# Language: Mathematica
# Processing rohanp
# Language: JavaScript
# Processing RoninXj
# Language: JavaScript
# Processing rosenpass
# Language: Rust
# Processing rpmuller
# Language: C
# Processing rsln-s
# Language: Jupyter Notebook
# Processing rubenandrebarreiro
# Language: Jupyter Notebook
# Processing rustpq
# Language: Rust
# Processing S4Plus
# Language: Unknown
# Can't process S4Plus as it is not a supported language
# Processing SaashaJoshi
# Language: Jupyter Notebook
# Processing salcc
# Language: Jupyter Notebook
# Processing samn33
# Language: Python
# Processing sandbox-quantum
# Language: Rust
# Processing sanshar
# Language: C
# Processing sbalian
# Language: Python
# Processing SchusterLab
# Language: Jupyter Notebook
# Processing SciML
# Language: Julia
# Processing Scinawa
# Language: Python
# Processing scottwn
# Language: Python
# Processing SebWouters
# Language: C++
# Processing SEDSCelestiaBPGC
# Language: Python
# Processing Semporia
# Language: JavaScript
# Processing sequence-toolbox
# Language: C++
# Processing sequencing-dev
# Language: Python
# Processing serenity
# Language: C++
# Processing sfc-aqua
# Language: Apex
# Can't process sfc-aqua as it is not a supported language
# Processing shankar1729
# Language: Python
# Processing shareloqs
# Language: Julia
# Processing Shi-aqi
# Language: JavaScript
# Processing shinmorino
# Language: C++
# Processing shmegb
# Language: Jupyter Notebook
# Processing Shmoo137
# Language: Jupyter Notebook
# Processing shuaigroup
# Language: Python
# Processing sirmarcel
# Language: Python
# Processing sissaschool
# Language: Fortran
# Processing Sliverkiss
# Language: JavaScript
# Processing slohani-ai
# Language: Jupyter Notebook
# Processing slowy07
# Language: Unknown
# Can't process slowy07 as it is not a supported language
# Processing SnowflurrySDK
# Language: Julia
# Processing softberg
# Language: PHP
# Processing softwareQinc
# Language: OpenQASM
# Can't process softwareQinc as it is not a supported language
# Processing SoftwareQuTech
# Language: Python
# Processing solikethis
# Language: Unknown
# Can't process solikethis as it is not a supported language
# Processing songyangzz
# Language: JavaScript
# Processing sophchoe
# Language: Jupyter Notebook
# Processing sphincs
# Language: C
# Processing splch
# Language: Jupyter Notebook
# Processing Spooky-Manufacturing
# Language: C
# Processing sQUlearn
# Language: Python
# Processing SRI-International
# Language: Jupyter Notebook
# Processing SSCHAcode
# Language: Python
# Processing sshi27
# Language: Kotlin
# Processing stafford-computing
# Language: Python
# Processing stanfordLINQS
# Language: Python
# Processing stared
# Language: R
# Processing stefnotch
# Language: TypeScript
# Processing stephenhky
# Language: Python
# Processing stewdio
# Language: JavaScript
# Processing Strilanc
# Language: JavaScript
# Processing style-qgan
# Language: Jupyter Notebook
# Processing stylewarning
# Language: Common Lisp
# Can't process stylewarning as it is not a supported language
# Processing sumeetkhatri
# Language: Python
# Processing sunqm
# Language: C
# Processing superstar54
# Language: Python
# Processing sve1r
# Language: JavaScript
# Processing sw1sh
# Language: Mathematica
# Processing SwiftQuantumComputing
# Language: Swift
# Processing symbolicsoft
# Language: Go
# Processing TeacherGaming
# Language: Java
# Processing TeamGraphix
# Language: Python
# Processing Technus
# Language: Java
# Processing tempoCollaboration
# Language: Jupyter Notebook
# Processing tencent-quantum-lab
# Language: Jupyter Notebook
# Processing TensorBFS
# Language: Python
# Processing tensorflow
# Language: Python
# Processing tensorly
# Language: Python
# Processing tequilahub
# Language: Python
# Processing terra-quantum-public
# Language: C++
# Processing theerfan
# Language: Jupyter Notebook
# Processing theochem
# Language: Python
# Processing theQRL
# Language: Python
# Processing thermo_pw
# Language: UnsupportedLanguage
# Can't process thermo_pw as it is not a supported language
# Processing thosgood
# Language: R
# Processing thu-pacman
# Language: C++
# Processing TigrisCallidus
# Language: UnsupportedLanguage
# Can't process TigrisCallidus as it is not a supported language
# Processing TitleOS
# Language: C#
# Processing tmancal74
# Language: Python
# Processing tomdbar
# Language: Python
# Processing Toperlock
# Language: TypeScript
# Processing tqsd
# Language: Python
# Processing TREX-CoE
# Language: C
# Processing triqs
# Language: UnsupportedLanguage
# Can't process triqs as it is not a supported language
# Processing txhaug
# Language: Jupyter Notebook
# Processing TY1ung
# Language: JavaScript
# Processing unimauro
# Language: Jupyter Notebook
# Processing uniqueque
# Language: JavaScript
# Processing unitaryfund
# Language: C++
# Processing USCCACS
# Language: Fortran
# Processing USCqserver
# Language: Jupyter Notebook
# Processing usnistgov
# Language: Python
# Processing UTokyo-ICEPP
# Language: Python
# Processing v-sivak
# Language: Python
# Processing ValeevGroup
# Language: C++
# Processing Vashistha-1802
# Language: Python
# Processing veorq
# Language: UnsupportedLanguage
# Can't process veorq as it is not a supported language
# Processing vinayak2019
# Language: Jupyter Notebook
# Processing vprusso
# Language: Python
# Processing VQE
# Language: UnsupportedLanguage
# Can't process VQE as it is not a supported language
# Processing w37fhy
# Language: JavaScript
# Processing WagnerGroup
# Language: Python
# Processing wangleiphy
# Language: Julia
# Processing webqit
# Language: JavaScript
# Processing websemantics
# Language: UnsupportedLanguage
# Can't process websemantics as it is not a supported language
# Processing weiyesing
# Language: JavaScript
# Processing wg-quantum
# Language: LiveScript
# Processing Winter-Soren
# Language: TypeScript
# Processing wmazin
# Language: Jupyter Notebook
# Processing WMD-group
# Language: Python
# Processing womanium-quantum
# Language: UnsupportedLanguage
# Can't process womanium-quantum as it is not a supported language
# Processing WonJoon-Yun
# Language: Python
# Processing wonmor
# Language: JavaScript
# Processing wztzjhn
# Language: C++
# Processing XanaduAI
# Language: C++
# Processing xiaoyu2018
# Language: Python
# Processing xuandrew
# Language: JavaScript
# Processing xwxiewu
# Language: UnsupportedLanguage
# Can't process xwxiewu as it is not a supported language
# Processing xx-labs
# Language: Go
# Processing yambo-code
# Language: Python
# Processing yangtingxiao
# Language: UnsupportedLanguage
# Can't process yangtingxiao as it is not a supported language
# Processing yardstiq
# Language: OpenQASM
# Can't process yardstiq as it is not a supported language
# Processing yawenchim
# Language: JavaScript
# Processing yezhengkai
# Language: UnsupportedLanguage
# Can't process yezhengkai as it is not a supported language
# Processing yifan1207
# Language: Python
# Processing yongshanding
# Language: Python
# Processing yqc007
# Language: JavaScript
# Processing yuanhangzhang98
# Language: Python
# Processing yuewuo
# Language: Rust
# Processing yunseo-kim
# Language: Jupyter Notebook
# Processing yurialexeev
# Language: Jupyter Notebook
# Processing yutuer21
# Language: Jupyter Notebook
# Processing yyn618
# Language: JavaScript
# Processing zapata-engineering
# Language: Python
# Processing zapatacomputing
# Language: Python
# Processing zlatko-minev
# Language: Jupyter Notebook
# Processing zoran-cuckovic
# Language: Python
# Processing zqzess
# Language: JavaScript
# Analysis complete. Results saved to repository_comments.json

# %%
# Cell 6: Step 1: Define keywords v1
keywords = {
    "General Quantum Algorithms": ["algorithm", "search", "walk", "Fourier transform", "phase estimation", "hidden subgroup problem", "speedup","optimization", "teleportation"],
    "Grover's Algorithm": ["grover", "amplitude amplification", "search", "algorithm"],
    "Shor's Algorithm": ["shor","algorithm","shor's algorithm","fraction", "fractals", "factorization", "integer factorization", "period finding", "order finding", "discrete logarithm", "RSA", "elliptic curve", "cryptography", "quantum-safe", "quantum-resistant"],
    "Variational Quantum Eigensolver (VQE)": ["variational eigensolver","algorithm", "vqe", "chemistry", "simulation"],
    "Quantum Approximate Optimization Algorithm (QAOA)": ["approximate optimization algorithm", "qaoa", "optimization","algorithm", "maxcut", "traveling salesman", "tsp", "combinatorial optimization", "graph partitioning", "scheduling", "routing"],
    "HHL Algorithm": ["hhl algorithm", "linear systems", "matrix inversion", "algorithm"],
    "Deutsch-Jozsa Algorithm": ["deutsch-jozsa", "balanced function", "constant function","algorithm"],
    "Simon's Algorithm": ["simon", "simon’s algorithm", "periodicity", "hidden period", "algorithm"],
    "General Quantum Cryptography": ["security","cryptography", "encryption", "secure direct communication", "post-cryptography", "network", "repeater", "hacking", "side-channel attack", "bit commitment", "digital signatures", "secret sharing", "secure comunication", "quantum-safe", "quantum-resistant"],
    "Quantum key distirbution ": ["quantum key distirbution", "security", "bb84","b92", "single-photon QKD", "cryptography",  "key distribution", "qkd", "encryption", "Alice", "Bob", "Eve", "e91", "entanglement-based QKD", "entanglement", "ekert protocol",],
    "Quantum Simulation": ["hamiltonian simulation",  "wavefunction", "many-body systems", "phase transition", "dynamics", "Monte Carlo", "lattice models", "fermionic simulation", "bosonic simulation", "chemistry", "variational eigensolver", "vqe", "unitary coupled cluster", "molecular dynamics", "field theory", "digital simulation", "analog simulation", "chaos", "adiabatic simulation", "quantum walk", "quantum cellular automata"],
    "Quantum Hardware": ["superconducting", "trapped ions",  "topological qubit", "decoherence", "error correction", "surface code",  "chip", "Josephson junction", "annealer", "processor", "transducer", "hybrid systems", "memristor"],
    "Quantum Machine Learning": ["neural networks", "qnn", "support vector machine", "qsvm", "clustering", "principal component analysis", "qpca", "Boltzmann machine", "qbms", "generative adversarial networks", "qgans", "hybrid classical machine learning", "data encoding", "feature mapping", "kernel estimation", "unsupervised learning", "reinforcement learning", "autoencoders", "classifier", "regression", "data"],
    "Quantum Communication": [
    "communication protocols", "coherent communication", "modulation",
    "communication complexity", "quantum internet", "quantum repeater",
    "quantum router", "quantum network", "quantum channel", "quantum link",
    "quantum relay", "quantum bridge", "quantum satellite"
],
    "Quantum Computer Tooling and Frameworks": ["development kit", "QDK", "SDK", "IDE", "programming environment", "emulation",  "circuit design", "circuit optimization", "gate library", "error correction tools", "debugging", "visualization tools", "benchmarking", "hardware integration", "cloud service", "API"],
    "Quantum Computer Simulation": ["quantum computing simulator","computer simulation","state vector simulation", "computer emulation", "circuit simulation", "hardware simulation", "system simulation", "software simulation", "virtual computer", "computing simulator", "emulator", "computing emulation", "circuit emulator", "state simulator", "gate simulator", "processor simulation", "algorithm simulation", ],
    "Learning Project": ["tutorial", "example", "learning project", "educational", "beginner", "introduction", "getting started", "hands-on", "course", "workshop", "training", "sample code", "demo", "guide", "instructional", "lesson", "walkthrough", "coding exercises", "teaching", "learning module"]
}

# %%
import re
from collections import Counter
from itertools import chain
import jellyfish

def preprocess_text(text):
    # Convert text to lowercase
    text = text.lower()
    # Remove punctuation and special characters
    text = re.sub(r'\W+', ' ', text)
    # Tokenize text
    tokens = text.split()
    return tokens

def generate_ngrams(tokens, n):
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

def extract_ngrams(text):
    tokens = preprocess_text(text)
    unigrams = tokens
    bigrams = generate_ngrams(tokens, 2)
    trigrams = generate_ngrams(tokens, 3)
    return unigrams + bigrams + trigrams

def classify_text(text, keyword_dict):
    ngrams = extract_ngrams(text)
    category_scores = {category: 0 for category in keyword_dict}

    for ngram in ngrams:
        for category, keywords in keyword_dict.items():
            if ngram in keywords:
                category_scores[category] += 1

    # Find the category with the highest score
    best_category = max(category_scores, key=category_scores.get)
    
    # Check if no keywords were matched
    if category_scores[best_category] == 0:
        return "No match found", category_scores
    
    return best_category, category_scores



def aggregate_comments(repo_comments):
    # Combine all comments into a single string
    combined_comments = ' '.join(repo_comments)
    return combined_comments


def classify_text(text, keyword_dict, threshold=0.90):
    ngrams = extract_ngrams(text)
    category_scores = {category: 0 for category in keyword_dict}

    for ngram in ngrams:
        for category, keywords in keyword_dict.items():
            for keyword in keywords:
                similarity = jellyfish.jaro_winkler_similarity(ngram, keyword)
                if similarity >= threshold:
                    category_scores[category] += 1

    # Find the category with the highest score
    best_category = max(category_scores, key=category_scores.get)

    # Check if no keywords were matched
    if category_scores[best_category] == 0:
        return "No match found", category_scores

    return best_category, category_scores

# %%
def classify_repositories(repositories, keyword_dict, threshold=0.85):
    repo_classifications = {}
    for repo_name, comments in repositories.items():
        combined_comments = aggregate_comments(comments)
        category_name, scores = classify_text(combined_comments, keyword_dict, threshold)

        repo_classifications[repo_name] = category_name, scores
    return repo_classifications

# Example comments for a repository
repo_comments = "coding 8 0 7 0 0 3 0 0 34 2 amazon 1 18 0 coding 8 0 7 0 0 3 0 0 34 2 amazon 1 18 0 coding 8 set attribute product device set method simulator simulator stabilizer simulator simulator complex imaginary zero maybe coding 8 c library following must equal definition h kind circuit visualization 1 1 1 parameter 2 2 1 parameter measurement coding 8 coding 8 non selective measurement selective measurement mat mat entropy mutual information relative entropy p dot conjugate operate gate operate c library coding 8 stabilizer coding 8 coding 8 self c library coding 8 get stats measurement self change change measurement operate gate operate quantum circuit coding 8 ex x 1 ex x 1 z 0 constant term include product coding 8 c library observable coding 8 coding 8 show method show method append single gate append group 1 gate padding line 0 line 1 line 2 3 line 3 4 header include file definition description gate operation random generation 1 gate 1 1 parameter gate 2 gate 2 1 parameter gate delete extra gate kind must int must list int para none para must list float c none c must int none must int self kind para c check check 1 gate p gate 2 gate non unitary gate operate gate gate c gate operate quantum circuit c library coding 8 1 gate 2 gate 3 gate n gate target register controlled psi psi pi 2 1 unit pi radian operate product reset measure coding 8 none measurement operate gate operate quantum circuit c library coding 8 coding 8 measurement 1st last 1 measurement last measurement operate gate operate quantum circuit c library stabilizer coding 8 number check number check number check number check number check number check number check id number check number check number check number check number check number check number check id 0 number read check section check key raise exception invalid key defined raise exception required key defined coding 8 coding 8 1 0 parameter gate 1 1 parameter gate 2 0 parameter gate 2 1 parameter gate supported unitary gate exist non unitary gate measure rest 1 mean measured 0 measured store c classical register allowed operating unitary gate measured limitation ex 0 1 2 2 1 0 2 1 0 1 1 gate gate redefine measured info ex 0 1 2 2 1 0 2 1 0 1 1 1 2 1 0 1 1 2 0 0 1 1 1 1 none 0 1 2 2 1 0 1 1 marginal frequency measured coding 8 set execute circuit measurement gate included 1 0 parameter gate 1 1 parameter gate 2 1 parameter gate coding 8 coding 8 coding 8 coding 8 1 0 parameter gate 1 1 parameter gate 1 2 parameter gate 1 3 parameter gate 2 0 parameter gate 2 1 parameter gate 2 2 parameter gate 2 3 parameter gate initialize measurement gate measurement gate supported defined gate sign definition rotation gate error check error check error check list binary vector bit integer ex 5 0 2 0 2 5 0 1 2 2 0 1 bit list probability frequency last quantum state coding 8 coding 8"
    

# Example repositories with comments
repositories = {
    "Repo1": ["This code uses Grover's algorithm for database search.", "We implemented the HHL algorithm for solving linear systems.", "The quantum circuit design is optimized for superconducting qubits."],
    "Repo2": ["Quantum key distribution (QKD) ensures secure communication.", "Implemented BB84 protocol for QKD.", "Encryption and secure communication with QKD."],
    "Repo3": ["coding 8 0 7 0 0 3 0 0 34 2 amazon 1 18 0 coding 8 0 7 0 0 3 0 0 34 2 amazon 1 18 0 coding 8 set attribute product device set method simulator simulator stabilizer simulator simulator complex imaginary zero maybe coding 8 c library following must equal definition h kind circuit visualization 1 1 1 parameter 2 2 1 parameter measurement coding 8 coding 8 non selective measurement selective measurement mat mat entropy mutual information relative entropy p dot conjugate operate gate operate c library coding 8 stabilizer coding 8 coding 8 self c library coding 8 get stats measurement self change change measurement operate gate operate quantum circuit coding 8 ex x 1 ex x 1 z 0 constant term include product coding 8 c library observable coding 8 coding 8 show method show method append single gate append group 1 gate padding line 0 line 1 line 2 3 line 3 4 header include file definition description gate operation random generation 1 gate 1 1 parameter gate 2 gate 2 1 parameter gate delete extra gate kind must int must list int para none para must list float c none c must int none must int self kind para c check check 1 gate p gate 2 gate non unitary gate operate gate gate c gate operate quantum circuit c library coding 8 1 gate 2 gate 3 gate n gate target register controlled psi psi pi 2 1 unit pi radian operate product reset measure coding 8 none measurement operate gate operate quantum circuit c library coding 8 coding 8 measurement 1st last 1 measurement last measurement operate gate operate quantum circuit c library stabilizer coding 8 number check number check number check number check number check number check number check id number check number check number check number check number check number check number check id 0 number read check section check key raise exception invalid key defined raise exception required key defined coding 8 coding 8 1 0 parameter gate 1 1 parameter gate 2 0 parameter gate 2 1 parameter gate supported unitary gate exist non unitary gate measure rest 1 mean measured 0 measured store c classical register allowed operating unitary gate measured limitation ex 0 1 2 2 1 0 2 1 0 1 1 gate gate redefine measured info ex 0 1 2 2 1 0 2 1 0 1 1 1 2 1 0 1 1 2 0 0 1 1 1 1 none 0 1 2 2 1 0 1 1 marginal frequency measured coding 8 set execute circuit measurement gate included 1 0 parameter gate 1 1 parameter gate 2 1 parameter gate coding 8 coding 8 coding 8 coding 8 1 0 parameter gate 1 1 parameter gate 1 2 parameter gate 1 3 parameter gate 2 0 parameter gate 2 1 parameter gate 2 2 parameter gate 2 3 parameter gate initialize measurement gate measurement gate supported defined gate sign definition rotation gate error check error check error check list binary vector bit integer ex 5 0 2 0 2 5 0 1 2 2 0 1 bit list probability frequency last quantum state coding 8 coding 8"],
}

# Classify repositories
repo_classifications = classify_repositories(repositories, keywords)
for repo, category in repo_classifications.items():
    print(f"Repository: {repo}, Category: {category}")
# Out:
# Repository: Repo1, Category: ('Quantum Communication', {'General Quantum Algorithms': 14, "Grover's Algorithm": 15, "Shor's Algorithm": 11, 'Variational Quantum Eigensolver (VQE)': 9, 'Quantum Approximate Optimization Algorithm (QAOA)': 11, 'HHL Algorithm': 17, 'Deutsch-Jozsa Algorithm': 9, "Simon's Algorithm": 9, 'General Quantum Cryptography': 2, 'Quantum key distirbution ': 3, 'Quantum Simulation': 2, 'Quantum Hardware': 3, 'Quantum Machine Learning': 2, 'Quantum Communication': 18, 'Quantum Computer Tooling and Frameworks': 4, 'Quantum Computer Simulation': 13, 'Learning Project': 0})
# Repository: Repo2, Category: ('Quantum Communication', {'General Quantum Algorithms': 0, "Grover's Algorithm": 0, "Shor's Algorithm": 3, 'Variational Quantum Eigensolver (VQE)': 0, 'Quantum Approximate Optimization Algorithm (QAOA)': 0, 'HHL Algorithm': 0, 'Deutsch-Jozsa Algorithm': 0, "Simon's Algorithm": 0, 'General Quantum Cryptography': 20, 'Quantum key distirbution ': 18, 'Quantum Simulation': 3, 'Quantum Hardware': 0, 'Quantum Machine Learning': 0, 'Quantum Communication': 38, 'Quantum Computer Tooling and Frameworks': 0, 'Quantum Computer Simulation': 1, 'Learning Project': 0})
# Repository: Repo3, Category: ('Quantum Computer Simulation', {'General Quantum Algorithms': 0, "Grover's Algorithm": 0, "Shor's Algorithm": 17, 'Variational Quantum Eigensolver (VQE)': 7, 'Quantum Approximate Optimization Algorithm (QAOA)': 0, 'HHL Algorithm': 4, 'Deutsch-Jozsa Algorithm': 3, "Simon's Algorithm": 0, 'General Quantum Cryptography': 14, 'Quantum key distirbution ': 16, 'Quantum Simulation': 18, 'Quantum Hardware': 9, 'Quantum Machine Learning': 5, 'Quantum Communication': 91, 'Quantum Computer Tooling and Frameworks': 99, 'Quantum Computer Simulation': 100, 'Learning Project': 60})
